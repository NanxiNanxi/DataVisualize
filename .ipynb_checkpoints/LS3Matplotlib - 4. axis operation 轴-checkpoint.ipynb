# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = range(10)
y = range(10)

fig = plt.gca()
plt.plot(x,y)

# set visibility of x and y axis
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)

# %%
import math
x = np.random.normal(loc=0.0, scale = 1.0, size = 300)
width = 0.5
bins = np.arange(math.floor(x.min())-width, math.ceil(x.max())+width,width)

ax = plt.subplot(111)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tick_params(bottom='off',top='off',left='off')
plt.grid()
plt.hist(x,alpha = 0.5, bins= bins)
# Out:
# (array([ 0.,  0.,  5., 21., 31., 46., 56., 49., 49., 23., 10.,  7.,  3.]),
#  array([-3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,
#          2. ,  2.5,  3. ]),
#  <a list of 13 Patch objects>)

# %%
import matplotlib as mpl #设置全局指标，标题文字大小
mpl.rcParams['axes.titlesize'] = '20'

# %%
x = range(10)
y = range(10)

#变量与str的结合
labels = ['label %d'%i for i in range(10)]
fig,ax = plt.subplots()

plt.plot(x,y)

ax.set_xticklabels(labels, rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'label 0'),
#  Text(0, 0, 'label 1'),
#  Text(0, 0, 'label 2'),
#  Text(0, 0, 'label 3'),
#  Text(0, 0, 'label 4'),
#  Text(0, 0, 'label 5'),
#  Text(0, 0, 'label 6')]

# %%
x = np.arange(10)
for i in range(1,4):
    plt.plot(x,i*x**2,label = 'Group %d' %i)
plt.legend(loc = 'best') #'upper left'

# %%
fig = plt.figure()
ax = plt.subplot(111)
x = np.arange(10)

for i in range(1,4):
    plt.plot(x,i*x**2,label = 'Group %d'%i)
   #bbox_to_anchor设置注解box所处位置, ncol设置一行有几个group
ax.legend(loc = 'upper center',bbox_to_anchor = (0.5,1.15), ncol = 3)

# %%
x = np.arange(10)
plt.title('Title')
for i in range(1,4):
    plt.plot(x,i*x**2,label = 'Group %d' %i,marker = 'o')
plt.legend(loc = 'upper right',framealpha = 0.1)
